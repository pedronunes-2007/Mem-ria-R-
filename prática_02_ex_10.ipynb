# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoarthurts08/cco-fundprog-unit-2026.1/blob/entrega-aula-02/pr%C3%A1tica_02_ex_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  print('          | 1 - SOMAR | 2 - SUBTRAIR | 3 - SAIR |           ')
  print('-------------------------------------------------------------')
  menu = int(input('Escolha uma das opções acima para navegar entre o programa: '))
  print('-------------------------------------------------------------')

  if menu == 1:
    print('[CALCULADORA DE SOMA]')
    s1 = float(input('\nInsira o primeiro número da soma: '))
    s2 = float(input('Insira o segundo número da soma: '))
    soma = s1 + s2
    print(f'--> {s1} + {s2} = {soma}\n')
    print('-------------------------------------------------------------')

  elif menu == 2:
    print('[CALCULADORA DE SUBTRAÇÃO]')
    sub1 = float(input('\nInsira o primeiro número da subtração: '))
    sub2 = float(input('Insira o segundo número da subtração: '))
    subtracao = sub1 - sub2
    print(f'--> {sub1} - {sub2} = {subtracao}\n')
    print('-------------------------------------------------------------')

  elif menu == 3:
    print('\nPrograma encerrado!')
    print('=============================================================')
    break

  else:
    print('[OPÇÃO INVÁLIDA]')
    print('-------------------------------------------------------------')
# Out:
#           | 1 - SOMAR | 2 - SUBTRAIR | 3 - SAIR |
# -------------------------------------------------------------
# Escolha uma das opções acima para navegar entre o programa: 8
# -------------------------------------------------------------
# [OPÇÃO INVÁLIDA]
# -------------------------------------------------------------
#           | 1 - SOMAR | 2 - SUBTRAIR | 3 - SAIR |
# -------------------------------------------------------------
# Escolha uma das opções acima para navegar entre o programa: 1
# -------------------------------------------------------------
# [CALCULADORA DE SOMA]
#
# Insira o primeiro número da soma: 318
# Insira o segundo número da soma: 1
# --> 318.0 + 1.0 = 319.0
#
# -------------------------------------------------------------
#           | 1 - SOMAR | 2 - SUBTRAIR | 3 - SAIR |
# -------------------------------------------------------------
# Escolha uma das opções acima para navegar entre o programa: 2
# ...
